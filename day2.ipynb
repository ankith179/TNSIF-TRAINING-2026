# %% [markdown]
# <a href="https://colab.research.google.com/github/ankith179/TNSIF-TRAINING-2026/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Practiced Below Programs**
# 1. Print "Hello World".
# 2. Store your name in a variable and print it.
# 3. Store age and display it.
# 4. Add two numbers.
# 5. Subract two numbers
# 6. Multiply two numbers
# 7. Divide two numbers
# 8. Find square of a number
# 9. Find cube of a number
# 10. Swap two variables

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Ankith"
print(name)
# Out:
# Ankith

# %%
age = 23
print(age)
# Out:
# 23

# %%
num1 = 25
num2  = 65
print("Add",num1+num2)
print("Sub", num2 - num1)
print("Mul",num1 * num2)
print("Div", num2 / num1)
#square root and cube root
print(num1**2)
print(num2**2)
print(num1**3)
print(num2**3)
# Out:
# Add 90
# Sub 40
# Mul 1625
# Div 2.6
# 625
# 4225
# 15625
# 274625

# %%
#swap 2 variables
temp = num1
num1 = num2
num2 = temp
print(num1, num2)
# Out:
# 25 65

# %%
#swap 2 variables without temp
num3 = 56
num4 = 43
num3 = num3 + num4
num4 = num3 - num4
num3 = num3 - num4
print(num3, num4)
# Out:
# 65 25

# %%
num3, num2 = num2, num3
print(num3, num2)
# Out:
# 65 43
